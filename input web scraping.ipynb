# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
data = pd.read_csv(r'C:\Users\Nizam Bakshi\Desktop\INTERNSHIP\20211030 Test Assignment\Input.csv')

# %%
data
# Out:
#                                                   URL
# 0   https://insights.blackcoffer.com/rising-it-cit...
# 1   https://insights.blackcoffer.com/rising-it-cit...
# 2   https://insights.blackcoffer.com/internet-dema...
# 3   https://insights.blackcoffer.com/rise-of-cyber...
# 4   https://insights.blackcoffer.com/ott-platform-...
# ..                                                ...
# 95  https://insights.blackcoffer.com/what-is-the-r...
# 96  https://insights.blackcoffer.com/impact-of-cov...
# 97  https://insights.blackcoffer.com/contribution-...
# 98  https://insights.blackcoffer.com/how-covid-19-...
# 99  https://insights.blackcoffer.com/how-will-covi...
#
# [100 rows x 1 columns]

# %%
data.count()
# Out:
# URL    100
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   URL     100 non-null    object
# dtypes: object(1)
# memory usage: 928.0+ bytes

# %%
data.dtypes
# Out:
# URL    object
# dtype: object

# %%
# as we need to extract the article heading and context for the 100 url we need to get the first data from the 1st url

# %%
url = 'https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/'

# %%
page = requests.get(url)

# %%
page
# Out:
# <Response [200]>

# %%
# we have get the access for the url

# %%
page.content
# Out:
# b'<!doctype html >\r\n<!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->\r\n<!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->\r\n<!--[if gt IE 8]><!--> <html lang="en-US"> <!--<![endif]-->\r\n<head>\r\n    <title>Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040. - Blackcoffer Insights</title>\r\n    <meta charset="UTF-8" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n    <link rel="pingback" href="https://insights.blackcoffer.com/xmlrpc.php" />\r\n    <meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n\n\t<!-- This site is optimized with the Yoast SEO plugin v21.1 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<link rel="canonical" href="https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/" />\n\t<meta property="og:loc
# ...

# %%
# as the content is in bytes type we need to convert it into html format

# %%
type(page.content)
# Out:
# bytes

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html >
#
# <!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->
# <!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en-US"> <!--<![endif]-->
# <head>
# <title>Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040. - Blackcoffer Insights</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://insights.blackcoffer.com/xmlrpc.php" rel="pingback"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
# <!-- This site is optimized with the Yoast SEO plugin v21.1 - https://yoast.com/wordpress/plugins/seo/ -->
# <link href="https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# ...

# %%
# as we need only the article head and its content from the url

# %%
article_head = soup.find('h1', attrs = {'class' :'entry-title'})

# %%
article_head
# Out:
# <h1 class="entry-title">Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040.</h1>

# %%
# as it extracted the article head from the page but we need it in text form so

# %%
article_head = soup.find('h1', attrs = {'class' :'entry-title'}).text.strip()

# %%
article_head
# Out:
# 'Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040.'

# %%
# now we have got the clean form of the data

# %%
# we will same proceed with its context

# %%
article_content = soup.find('div', attrs = {'class' : 'td-post-content tagdiv-type'})

# %%
article_content
# Out:
# <div class="td-post-content tagdiv-type">
# <p>We have seen a huge development and dependence of people on technology in recent years. We have also seen the development of AI and ChatGPT in recent years. So it is a normal thing that we will become fully dependent on technology by 2040. Information technology will be a major power for all the developing nations. As a member of a developing nation, India is rapidly growing its IT base. It has also grown some IT cities which will be the major control centres for Information technology by 2040.</p>
# <p><strong><u>Rising IT cities</u></strong></p>
# <ol type="1">
# ...

# %%
# similarly we want it in text form

# %%
article_content = soup.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip()

# %%
article_content
# Out:
# 'We have seen a huge development and dependence of people on technology in recent years. We have also seen the development of AI and ChatGPT in recent years. So it is a normal thing that we will become fully dependent on technology by 2040. Information technology will be a major power for all the developing nations. As a member of a developing nation, India is rapidly growing its IT base. It has also grown some IT cities which will be the major control centres for Information technology by 2040.\nRising IT cities\n\nNoida:- Noida in Uttar Pradesh near New Delhi is an emerging IT sector now. Many large companies like Google, Microsoft, IBM, Infosys and others have set up their companies here. Noida has a market base of billions of dollars and is doing a great job of boosting the national economy. The establishment of so many software companies has made Noida an information technology hub.\nGurgaon:- Gurgaon in Haryana is also an emerging IT hub. Many large companies like Google, Micro
# ...

# %%
# as there are some attribute like \n and \xa0 we need to remove it to get it in clear form

# %%
article_content = soup.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n', " ").replace('\xa0', " ")

# %%
article_content
# Out:
# 'We have seen a huge development and dependence of people on technology in recent years. We have also seen the development of AI and ChatGPT in recent years. So it is a normal thing that we will become fully dependent on technology by 2040. Information technology will be a major power for all the developing nations. As a member of a developing nation, India is rapidly growing its IT base. It has also grown some IT cities which will be the major control centres for Information technology by 2040. Rising IT cities  Noida:- Noida in Uttar Pradesh near New Delhi is an emerging IT sector now. Many large companies like Google, Microsoft, IBM, Infosys and others have set up their companies here. Noida has a market base of billions of dollars and is doing a great job of boosting the national economy. The establishment of so many software companies has made Noida an information technology hub. Gurgaon:- Gurgaon in Haryana is also an emerging IT hub. Many large companies like Google, Microsoft
# ...

# %%
# as we have extracted the article heading and its content from the url we make a data of it by combining both of them

# %%
data1 = [[article_head, article_content]]

# %%
data1
# Out:
# [['Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040.',
# ...

# %%
# as we have done this to extract one article heading and its content we can procced with loop as we need to get it into loop

# %%
url2 = 'https://insights.blackcoffer.com/rising-it-cities-and-their-impact-on-the-economy-environment-infrastructure-and-city-life-in-future/'

# %%
page2= requests.get(url2)

# %%
page2
# Out:
# <Response [200]>

# %%
page2.content
# Out:
# b'<!doctype html >\r\n<!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->\r\n<!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->\r\n<!--[if gt IE 8]><!--> <html lang="en-US"> <!--<![endif]-->\r\n<head>\r\n    <title>Rising IT Cities and Their Impact on the Economy, Environment, Infrastructure, and City Life in Future - Blackcoffer Insights</title>\r\n    <meta charset="UTF-8" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\r\n    <link rel="pingback" href="https://insights.blackcoffer.com/xmlrpc.php" />\r\n    <meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n\n\t<!-- This site is optimized with the Yoast SEO plugin v21.1 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<link rel="canonical" href="https://insights.blackcoffer.com/rising-it-cities-and-their-impact-on-the-economy-environment-infrastructure-and-city-life-in-future/" />\n\t<meta property="og:locale" content=
# ...

# %%
soup2 = BeautifulSoup(page2.content, "html.parser")

# %%
article_head2 = soup2.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content2 = soup2.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data2= [[article_head2, article_content2]]

# %%
data2
# Out:
# [['Rising IT Cities and Their Impact on the Economy, Environment, Infrastructure, and City Life in Future',
# ...

# %%
url3 = 'https://insights.blackcoffer.com/internet-demands-evolution-communication-impact-and-2035s-alternative-pathways/'
page3= requests.get(url3)
page3
soup3 = BeautifulSoup(page3.content, "html.parser")
article_head3 = soup3.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content3 = soup3.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data3= [[article_head3, article_content3]]
data3
# Out:
# [['Internet Demand’s Evolution, Communication Impact, and 2035’s Alternative Pathways',
# ...

# %%
url4 = 'https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-in-upcoming-future/'
page4= requests.get(url4)
page4
soup4 = BeautifulSoup(page4.content, "html.parser")
article_head4 = soup4.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content4 = soup4.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data4= [[article_head4, article_content4]]
data4
# Out:
# [['Rise of Cybercrime and its Effect in upcoming Future',
# ...

# %%
url5= 'https://insights.blackcoffer.com/ott-platform-and-its-impact-on-the-entertainment-industry-in-future/'
page5= requests.get(url5)
page5
soup5 = BeautifulSoup(page5.content, "html.parser")
article_head5 = soup5.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content5 = soup5.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data5 =[[article_head5, article_content5]]
data5
# Out:
# [['OTT platform and its impact on the entertainment industry in Future.',
# ...

# %%
url6= 'https://insights.blackcoffer.com/the-rise-of-the-ott-platform-and-its-impact-on-the-entertainment-industry-by-2040/'
page6= requests.get(url6)
page6
soup6 = BeautifulSoup(page6.content, "html.parser")
article_head6 = soup6.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content6 = soup6.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data6= [[article_head6, article_content6]]
data6
# Out:
# [['The rise of the OTT platform and its impact on the entertainment industry by 2040.',
# ...

# %%
url7= 'https://insights.blackcoffer.com/rise-of-cyber-crime-and-its-effects/'
page7= requests.get(url7)
page7
soup7 = BeautifulSoup(page7.content, "html.parser")
article_head7 = soup7.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content7 = soup7.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data7= [[article_head7, article_content7]]
data7
# Out:
# [['Rise of Cyber Crime and its Effects',
# ...

# %%
url8= 'https://insights.blackcoffer.com/rise-of-internet-demand-and-its-impact-on-communications-and-alternatives-by-the-year-2035-2/'
page8= requests.get(url8)
page8
soup8 = BeautifulSoup(page8.content, "html.parser")
article_head8 = soup8.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content8 = soup8.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data8= [[article_head8, article_content8]]
data8
# Out:
# [['Rise of Internet Demand and Its Impact on Communications and Alternatives by the Year 2035',
# ...

# %%
url9= 'https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-by-the-year-2040-2/'
page9= requests.get(url9)
page9
soup9 = BeautifulSoup(page9.content, "html.parser")
article_head9 = soup9.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content9 = soup9.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data9= [[article_head9, article_content9]]
data9
# Out:
# [['Rise of Cybercrime and its Effect by the Year 2040.',
# ...

# %%
url10= 'https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-by-the-year-2040/'
page10= requests.get(url10)
page10
soup10 = BeautifulSoup(page10.content, "html.parser")
article_head10 = soup10.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content10 = soup10.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0', " ")
data10= [[article_head10, article_content10]]
data10
# Out:
# [['Rise of Cybercrime and its Effect by the Year 2040.',
# ...

# %%
url11= 'https://insights.blackcoffer.com/rise-of-internet-demand-and-its-impact-on-communications-and-alternatives-by-the-year-2035/'
page11= requests.get(url11)
page11
soup11 = BeautifulSoup(page11.content, "html.parser")
article_head11 = soup11.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content11 = soup11.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data11= [[article_head11, article_content11]]
data11
# Out:
# [['Rise of Internet Demand and its Impact on Communications and Alternatives by the Year 2035.',
# ...

# %%
url12= 'https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-3-2/'
page12= requests.get(url12)
page12
soup12 = BeautifulSoup(page12.content, "html.parser")
article_head12 = soup12.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content12 = soup12.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data12= [[article_head12, article_content12]]
data12
# Out:
# [['Rise of telemedicine and its Impact on Livelihood by 2040',
# ...

# %%
url13= 'https://insights.blackcoffer.com/rise-of-e-health-and-its-impact-on-humans-by-the-year-2030/'
page13= requests.get(url13)
page13
soup13 = BeautifulSoup(page13.content, "html.parser")
article_head13 = soup13.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content13 = soup13.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data13= [[article_head13, article_content13]]
data13
# Out:
# [['Rise of e-health and its impact on humans by the year 2030',
# ...

# %%
url14= 'https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030-2/'
page14= requests.get(url14)
page14
soup14 = BeautifulSoup(page14.content, "html.parser")
article_head14 = soup14.find('h1', attrs = {'class' :'tdb-title-text'}).text.strip()
article_content14 = soup14.find('div', attrs = {'class':'tdb-block-inner td-fix-index'}).text.strip()
data14= [[article_head14, article_content14]]
data14
# Out:
# [['Rise of e-health and its impact on humans by the year 2030', '']]

# %%
# unable to extract the data from url 14

# %%
url15= 'https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-2/'
page15= requests.get(url15)
page15
soup15 = BeautifulSoup(page15.content, "html.parser")
article_head15 = soup15.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content15 = soup15.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data15= [[article_head15, article_content15]]
data15
# Out:
# [['Rise of telemedicine and its Impact on Livelihood by 2040',
# ...

# %%
url16= 'https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-2-2/'
page16= requests.get(url16)
page16
soup16 = BeautifulSoup(page16.content, "html.parser")
article_head16 = soup16.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content16 = soup16.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data16= [[article_head16, article_content16]]
data16
# Out:
# [['Rise of telemedicine and its Impact on Livelihood by 2040',
# ...

# %%
url17= 'https://insights.blackcoffer.com/rise-of-chatbots-and-its-impact-on-customer-support-by-the-year-2040/'
page17= requests.get(url17)
page17
soup17 = BeautifulSoup(page17.content, "html.parser")
article_head17 = soup17.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content17 = soup17.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data17= [[article_head17, article_content17]]
data17
# Out:
# [['Rise of Chatbots and its impact on customer support by the year 2040',
# ...

# %%
url18= 'https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030/'
page18= requests.get(url18)
page18
soup18 = BeautifulSoup(page18.content, "html.parser")
article_head18 = soup18.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content18 = soup18.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data18= [[article_head18, article_content18]]
data18
# Out:
# [['Rise of e-health and its impact on humans by the year 2030',
# ...

# %%
url19= 'https://insights.blackcoffer.com/how-does-marketing-influence-businesses-and-consumers/'
page19= requests.get(url19)
page19
soup19 = BeautifulSoup(page19.content, "html.parser")
article_head19 = soup19.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content19 = soup19.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data19= [[article_head19, article_content19]]
data19
# Out:
# [['How does marketing influence businesses and consumers?',
# ...

# %%
url21= 'https://insights.blackcoffer.com/how-advertisement-increase-your-market-value/'
page21= requests.get(url21)
page21
soup21 = BeautifulSoup(page21.content, "html.parser")
article_head21 = soup21.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content21 = soup21.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data21= [[article_head21, article_content21]]
data21
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 5
#       3 page21
#       4 soup21 = BeautifulSoup(page21.content, "html.parser")
# ----> 5 article_head21 = soup21.find('h1', attrs = {'class' :'entry-title'}).text.strip()
#       6 article_content21 = soup21.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
#       7 data21= [[article_head21, article_content21]]
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
url22= 'https://insights.blackcoffer.com/negative-effects-of-marketing-on-society/'
page22= requests.get(url22)
page22
soup22 = BeautifulSoup(page22.content, "html.parser")
article_head22 = soup22.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content22 = soup22.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data22= [[article_head22, article_content22]]
data22
# Out:
# [['Negative effects of marketing on society',
# ...

# %%
url23= 'https://insights.blackcoffer.com/how-advertisement-marketing-affects-business/'
page23= requests.get(url23)
page23
soup23 = BeautifulSoup(page23.content, "html.parser")
article_head23 = soup23.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content23 = soup23.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data23= [[article_head23, article_content23]]
data23
# Out:
# [['How advertisement/marketing affects business.',
# ...

# %%
url24= 'https://insights.blackcoffer.com/rising-it-cities-will-impact-the-economy-environment-infrastructure-and-city-life-by-the-year-2035/'
page24= requests.get(url24)
page24
soup24 = BeautifulSoup(page24.content, "html.parser")
article_head24 = soup24.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content24 = soup24.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data24= [[article_head24, article_content24]]
data24
# Out:
# [['Rising IT cities will impact the economy, environment, infrastructure, and city life by the year 2035',
# ...

# %%
url25= 'https://insights.blackcoffer.com/rise-of-ott-platform-and-its-impact-on-entertainment-industry-by-the-year-2030/'
page25= requests.get(url25)
page25
soup25 = BeautifulSoup(page25.content, "html.parser")
article_head25 = soup25.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content25 = soup25.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data25= [[article_head25, article_content25]]
data25
# Out:
# [['Rise of OTT platform and its impact on entertainment industry by the year 2030',
# ...

# %%
url26= 'https://insights.blackcoffer.com/rise-of-electric-vehicles-and-its-impact-on-livelihood-by-2040/'
page26= requests.get(url26)
page26
soup26 = BeautifulSoup(page26.content, "html.parser")
article_head26 = soup26.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content26 = soup26.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data26= [[article_head26, article_content26]]
data26
# Out:
# [['Rise of Electric Vehicles and its Impact on Livelihood by 2040',
# ...

# %%
url27= 'https://insights.blackcoffer.com/rise-of-electric-vehicle-and-its-impact-on-livelihood-by-the-year-2040/'
page27= requests.get(url27)
page27
soup27 = BeautifulSoup(page27.content, "html.parser")
article_head27 = soup27.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content27 = soup27.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data27= [[article_head27, article_content27]]
data27
# Out:
# [['Rise of electric vehicle and its impact on livelihood by the year 2040.',
# ...

# %%
url28= 'https://insights.blackcoffer.com/oil-prices-by-the-year-2040-and-how-it-will-impact-the-world-economy/'
page28= requests.get(url28)
page28
soup28 = BeautifulSoup(page28.content, "html.parser")
article_head28 = soup28.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content28 = soup28.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data28= [[article_head28, article_content28]]
data28
# Out:
# [['Oil prices by the year 2040, and how it will impact the world economy.',
# ...

# %%
url29= 'https://insights.blackcoffer.com/an-outlook-of-healthcare-by-the-year-2040-and-how-it-will-impact-human-lives/'
page29= requests.get(url29)
page29
soup29 = BeautifulSoup(page29.content, "html.parser")
article_head29 = soup29.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content29 = soup29.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data29= [[article_head29, article_content29]]
data29
# Out:
# [['An outlook of healthcare by the year 2040, and how it will impact human lives.',
# ...

# %%
url30= 'https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/'
page30= requests.get(url30)
page30
soup30 = BeautifulSoup(page30.content, "html.parser")
article_head30 = soup30.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content30 = soup30.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data30= [[article_head30, article_content30]]
data30
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 5
#       3 page30
#       4 soup30 = BeautifulSoup(page30.content, "html.parser")
# ----> 5 article_head30 = soup30.find('h1', attrs = {'class' :'entry-title'}).text.strip()
#       6 article_content30 = soup30.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
#       7 data30= [[article_head30, article_content30]]
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
url31= 'https://insights.blackcoffer.com/what-if-the-creation-is-taking-over-the-creator/'
page31= requests.get(url31)
page31
soup31 = BeautifulSoup(page31.content, "html.parser")
article_head31 = soup31.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content31 = soup31.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data31= [[article_head31, article_content31]]
data31
# Out:
# [['What if the Creation is Taking Over the Creator?',
# ...

# %%
url32= 'https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/'
page32= requests.get(url32)
page32
soup32 = BeautifulSoup(page32.content, "html.parser")
article_head32 = soup32.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content32 = soup32.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ")
data32= [[article_head32, article_content32]]
data32
# Out:
# [['What Jobs Will Robots Take From Humans in The Future?',
# ...

# %%
url33= 'https://insights.blackcoffer.com/will-machine-replace-the-human-in-the-future-of-work/'
page33= requests.get(url33)
page33
soup33 = BeautifulSoup(page33.content, "html.parser")
article_head33 = soup33.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content33 = soup33.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0', " ")
data33= [[article_head33, article_content33]]
data33
# Out:
# [['Will Machine Replace The Human in the Future of Work?',
# ...

# %%
url34= 'https://insights.blackcoffer.com/will-ai-replace-us-or-work-with-us/'
page34= requests.get(url34)
page34
soup34 = BeautifulSoup(page34.content, "html.parser")
article_head34 = soup34.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content34 = soup34.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data34= [[article_head34, article_content34]]
data34
# Out:
# [['Will AI Replace Us or Work With Us?',
# ...

# %%
url35= 'https://insights.blackcoffer.com/man-and-machines-together-machines-are-more-diligent-than-humans-blackcoffe/'
page35= requests.get(url35)
page35
soup35 = BeautifulSoup(page35.content, "html.parser")
article_head35 = soup35.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content35 = soup35.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data35= [[article_head35, article_content35]]
data35
# Out:
# [['Will machine replace the human in the future of work?',
# ...

# %%
url36= 'https://insights.blackcoffer.com/in-future-or-in-upcoming-years-humans-and-machines-are-going-to-work-together-in-every-field-of-work/'
page36= requests.get(url36)
page36
soup36 = BeautifulSoup(page36.content, "html.parser")
article_head36 = soup36.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content36 = soup36.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data36= [[article_head36, article_content36]]
data36
# Out:
# [['How humans and machines are evolving to work together?',
# ...

# %%
url37= 'https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/'
page37= requests.get(url37)
page37
soup37 = BeautifulSoup(page37.content, "html.parser")
article_head37 = soup37.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content37 = soup37.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data37= [[article_head37, article_content37]]
data37
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 5
#       3 page37
#       4 soup37 = BeautifulSoup(page37.content, "html.parser")
# ----> 5 article_head37 = soup37.find('h1', attrs = {'class' :'entry-title'}).text.strip()
#       6 article_content37 = soup37.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
#       7 data37= [[article_head37, article_content37]]
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
url38= 'https://insights.blackcoffer.com/how-machine-learning-will-affect-your-business/'
page38= requests.get(url38)
page38
soup38 = BeautifulSoup(page38.content, "html.parser")
article_head38 = soup38.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content38 = soup38.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data38= [[article_head38, article_content38]]
data38
# Out:
# [['How machine learning will affect your business?',
# ...

# %%
url39= 'https://insights.blackcoffer.com/deep-learning-impact-on-areas-of-e-learning/'
page39= requests.get(url39)
page39
soup39 = BeautifulSoup(page39.content, "html.parser")
article_head39 = soup39.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content39 = soup39.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data39= [[article_head39, article_content39]]
data39
# Out:
# [['Deep learning impact on areas of e-learning?',
# ...

# %%
url40= 'https://insights.blackcoffer.com/how-to-protect-future-data-and-its-privacy-blackcoffer/'
page40= requests.get(url40)
page40
soup40 = BeautifulSoup(page40.content, "html.parser")
article_head40 = soup40.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content40 = soup40.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data40= [[article_head40, article_content40]]
data40
# Out:
# [['How to protect future data and its privacy?',
# ...

# %%
url41= 'https://insights.blackcoffer.com/how-machines-ai-automations-and-robo-human-are-effective-in-finance-and-banking/'
page41= requests.get(url41)
page41
soup41 = BeautifulSoup(page41.content, "html.parser")
article_head41 = soup41.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content41 = soup41.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data41= [[article_head41, article_content41]]
data41
# Out:
# [['How Machines, AI, Automations, and Robo-human are Effective in Finance and Banking?',
# ...

# %%
url42= 'https://insights.blackcoffer.com/ai-human-robotics-machine-future-planet-blackcoffer-thinking-jobs-workplace/'
page42= requests.get(url42)
page42
soup42 = BeautifulSoup(page42.content, "html.parser")
article_head42 = soup42.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content42 = soup42.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data42= [[article_head42, article_content42]]
data42
# Out:
# [['How Robo Human will Impact the Future?',
# ...

# %%
url43= 'https://insights.blackcoffer.com/how-ai-will-change-the-world-blackcoffer/'
page43= requests.get(url43)
page43
soup43 = BeautifulSoup(page43.content, "html.parser")
article_head43 = soup43.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content43 = soup43.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data43= [[article_head43, article_content43]]
data43
# Out:
# [['How AI will change the World?',
# ...

# %%
url44= 'https://insights.blackcoffer.com/future-of-work-how-ai-has-entered-the-workplace/'
page44= requests.get(url44)
page44
soup44 = BeautifulSoup(page44.content, "html.parser")
article_head44 = soup44.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content44 = soup44.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data44= [[article_head44, article_content44]]
data44
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 5
#       3 page44
#       4 soup44 = BeautifulSoup(page44.content, "html.parser")
# ----> 5 article_head44 = soup44.find('h1', attrs = {'class' :'entry-title'}).text.strip()
#       6 article_content44 = soup44.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
#       7 data44= [[article_head44, article_content44]]
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
url45= 'https://insights.blackcoffer.com/ai-tool-alexa-google-assistant-finance-banking-tool-future/'
page45= requests.get(url45)
page45
soup45 = BeautifulSoup(page45.content, "html.parser")
article_head45 = soup45.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content45 = soup45.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data45= [[article_head45, article_content45]]
data45
# Out:
# [['How machine learning used in finance and banking?',
# ...

# %%
url46= 'https://insights.blackcoffer.com/ai-healthcare-revolution-ml-technology-algorithm-google-analytics-industrialrevolution/'
page46= requests.get(url46)
page46
soup46 = BeautifulSoup(page46.content, "html.parser")
article_head46 = soup46.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content46 = soup46.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data46= [[article_head46, article_content46]]
data46
# Out:
# [['How AI will impact the future of work?',
# ...

# %%
url47= 'https://insights.blackcoffer.com/all-you-need-to-know-about-online-marketing/'
page47= requests.get(url47)
page47
soup47 = BeautifulSoup(page47.content, "html.parser")
article_head47 = soup47.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content47 = soup47.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data47= [[article_head47, article_content47]]
data47
# Out:
# [['All you need to know about online marketing',
# ...

# %%
url48= 'https://insights.blackcoffer.com/evolution-of-advertising-industry/'
page48= requests.get(url48)
page48
soup48 = BeautifulSoup(page48.content, "html.parser")
article_head48 = soup48.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content48 = soup48.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data48= [[article_head48, article_content48]]
data48
# Out:
# [['Evolution of Advertising Industry',
# ...

# %%
url49= 'https://insights.blackcoffer.com/how-data-analytics-can-help-your-business-respond-to-the-impact-of-covid-19/'
page49= requests.get(url49)
page49
soup49 = BeautifulSoup(page49.content, "html.parser")
article_head49 = soup49.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content49 = soup49.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data49= [[article_head49, article_content49]]
data49
# Out:
# [['How Data Analytics can help your business respond to the impact of COVID-19?',
# ...

# %%
url50= 'https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/'
page50= requests.get(url50)
page50
soup50 = BeautifulSoup(page50.content, "html.parser")
article_head50 = soup50.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content50 = soup50.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data50= [[article_head50, article_content50]]
data50
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[104], line 5
#       3 page50
#       4 soup50 = BeautifulSoup(page50.content, "html.parser")
# ----> 5 article_head50 = soup50.find('h1', attrs = {'class' :'entry-title'}).text.strip()
#       6 article_content50 = soup50.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
#       7 data50= [[article_head50, article_content50]]
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
url51= 'https://insights.blackcoffer.com/environmental-impact-of-the-covid-19-pandemic-lesson-for-the-future/'
page51= requests.get(url51)
page51
soup51 = BeautifulSoup(page51.content, "html.parser")
article_head51 = soup51.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content51 = soup51.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data51= [[article_head51, article_content51]]
data51
# Out:
# [['Environmental impact of the COVID-19 pandemic – Lesson for the Future',
# ...

# %%
url52= 'https://insights.blackcoffer.com/how-data-analytics-and-ai-are-used-to-halt-the-covid-19-pandemic/'
page52= requests.get(url52)
page52
soup52 = BeautifulSoup(page52.content, "html.parser")
article_head52 = soup52.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content52 = soup52.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data52= [[article_head52, article_content52]]
data52
# Out:
# [['How Data Analytics and AI are used to halt the COVID-19 Pandemic?',
# ...

# %%
url53= 'https://insights.blackcoffer.com/difference-between-artificial-intelligence-machine-learning-statistics-and-data-mining/'
page53= requests.get(url53)
page53
soup53 = BeautifulSoup(page53.content, "html.parser")
article_head53 = soup53.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content53 = soup53.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data53= [[article_head53, article_content53]]
data53
# Out:
# [['What is the difference between Artificial Intelligence, Machine Learning, Statistics, and Data Mining?',
# ...

# %%
url54= 'https://insights.blackcoffer.com/how-python-became-the-first-choice-for-data-science/'
page54= requests.get(url54)
page54
soup54 = BeautifulSoup(page54.content, "html.parser")
article_head54 = soup54.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content54 = soup54.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data54= [[article_head54, article_content54]]
data54
# Out:
# [['How Python became the first choice for Data Science.',
# ...

# %%
url55= 'https://insights.blackcoffer.com/how-google-fit-measure-heart-and-respiratory-rates-using-a-phone/'
page55= requests.get(url55)
page55
soup55 = BeautifulSoup(page55.content, "html.parser")
article_head55 = soup55.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content55 = soup55.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data55= [[article_head55, article_content55]]
data55
# Out:
# [['How Google fit measure heart and respiratory rates using a phone camera?',
# ...

# %%
url56= 'https://insights.blackcoffer.com/what-is-the-future-of-mobile-apps/'
page56= requests.get(url56)
page56
soup56 = BeautifulSoup(page56.content, "html.parser")
article_head56 = soup56.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content56 = soup56.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data56= [[article_head56, article_content56]]
data56
# Out:
# [['What is the future of mobile apps?',
# ...

# %%
url57= 'https://insights.blackcoffer.com/impact-of-ai-in-health-and-medicine/'
page57= requests.get(url57)
page57
soup57 = BeautifulSoup(page57.content, "html.parser")
article_head57 = soup57.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content57 = soup57.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data57= [[article_head57, article_content57]]
data57
# Out:
# [['Impact of AI in health and medicine',
# ...

# %%
url58= 'https://insights.blackcoffer.com/telemedicine-what-patients-like-and-dislike-about-it/'
page58= requests.get(url58)
page58
soup58 = BeautifulSoup(page58.content, "html.parser")
article_head58 = soup58.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content58 = soup58.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data58= [[article_head58, article_content58]]
data58
# Out:
# [['What patients like and dislike about telemedicine?',
# ...

# %%
url59= 'https://insights.blackcoffer.com/how-we-forecast-future-technologies/'
page59= requests.get(url59)
page59
soup59 = BeautifulSoup(page59.content, "html.parser")
article_head59 = soup59.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content59 = soup59.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data59= [[article_head59, article_content59]]
data59
# Out:
# [['How we forecast future technologies?',
# ...

# %%
url60= 'https://insights.blackcoffer.com/can-robots-tackle-late-life-loneliness/'
page60= requests.get(url60)
page60
soup60 = BeautifulSoup(page60.content, "html.parser")
article_head60 = soup60.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content60 = soup60.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data60= [[article_head60, article_content60]]
data60
# Out:
# [['Can robots tackle late-life loneliness?',
# ...

# %%
url61= 'https://insights.blackcoffer.com/embedding-care-robots-into-society-socio-technical-considerations/'
page61= requests.get(url61)
page61
soup61 = BeautifulSoup(page61.content, "html.parser")
article_head61 = soup61.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content61 = soup61.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data61= [[article_head61, article_content61]]
data61
# Out:
# [['Embedding care robots into society and practice: Socio-technical considerations',
# ...

# %%
url62= 'https://insights.blackcoffer.com/management-challenges-for-future-digitalization-of-healthcare-services/'
page62= requests.get(url62)
page62
soup62 = BeautifulSoup(page62.content, "html.parser")
article_head62 = soup62.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content62 = soup62.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data62= [[article_head62, article_content62]]
data62
# Out:
# [['Management challenges for future digitalization of healthcare services',
# ...

# %%
url63= 'https://insights.blackcoffer.com/are-we-any-closer-to-preventing-a-nuclear-holocaust/'
page63= requests.get(url63)
page63
soup63 = BeautifulSoup(page63.content, "html.parser")
article_head63 = soup63.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content63 = soup63.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data63= [[article_head63, article_content63]]
data63
# Out:
# [['Are we any closer to preventing a nuclear holocaust?',
# ...

# %%
url64= 'https://insights.blackcoffer.com/will-technology-eliminate-the-need-for-animal-testing-in-drug-development/'
page64= requests.get(url64)
page64
soup64 = BeautifulSoup(page64.content, "html.parser")
article_head64 = soup64.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content64 = soup64.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data64= [[article_head64, article_content64]]
data64
# Out:
# [['Will technology eliminate the need for animal testing in drug development?',
# ...

# %%
url65= 'https://insights.blackcoffer.com/will-we-ever-understand-the-nature-of-consciousness/'
page65= requests.get(url65)
page65
soup65 = BeautifulSoup(page65.content, "html.parser")
article_head65 = soup65.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content65 = soup65.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data65= [[article_head65, article_content65]]
data65
# Out:
# [['Will we ever understand the nature of consciousness?',
# ...

# %%
url66= 'https://insights.blackcoffer.com/will-we-ever-colonize-outer-space/'
page66= requests.get(url66)
page66
soup66 = BeautifulSoup(page66.content, "html.parser")
article_head66 = soup66.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content66 = soup66.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data66= [[article_head66, article_content66]]
data66
# Out:
# [['Will we ever colonize outer space?',
# ...

# %%
url67= 'https://insights.blackcoffer.com/what-is-the-chance-homo-sapiens-will-survive-for-the-next-500-years/'
page67= requests.get(url67)
page67
soup67 = BeautifulSoup(page67.content, "html.parser")
article_head67 = soup67.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content67 = soup67.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data67= [[article_head67, article_content67]]
data67
# Out:
# [['What is the chance Homo sapiens will survive for the next 500 years?',
# ...

# %%
url68= 'https://insights.blackcoffer.com/why-does-your-business-need-a-chatbot/'
page68= requests.get(url68)
page68
soup68 = BeautifulSoup(page68.content, "html.parser")
article_head68 = soup68.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content68 = soup68.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data68= [[article_head68, article_content68]]
data68
# Out:
# [['Why does your business need a chatbot?',
# ...

# %%
url69= 'https://insights.blackcoffer.com/how-you-lead-a-project-or-a-team-without-any-technical-expertise/'
page69= requests.get(url69)
page69
soup69 = BeautifulSoup(page69.content, "html.parser")
article_head69 = soup69.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content69 = soup69.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data69= [[article_head69, article_content69]]
data69
# Out:
# [['How you lead a project or a team without any technical expertise?',
# ...

# %%
url70= 'https://insights.blackcoffer.com/can-you-be-great-leader-without-technical-expertise/'
page70= requests.get(url70)
page70
soup70 = BeautifulSoup(page70.content, "html.parser")
article_head70 = soup70.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content70 = soup70.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data70= [[article_head70, article_content70]]
data70
# Out:
# [['Can You Be Great Leader Without Technical Expertise',
# ...

# %%
url71= 'https://insights.blackcoffer.com/how-does-artificial-intelligence-affect-the-environment/'
page71= requests.get(url71)
page71
soup71 = BeautifulSoup(page71.content, "html.parser")
article_head71 = soup71.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content71 = soup71.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data71= [[article_head71, article_content71]]
data71
# Out:
# [['How does artificial intelligence affect the environment',
# ...

# %%
url72= 'https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes-2/'
page72= requests.get(url72)
page72
soup72 = BeautifulSoup(page72.content, "html.parser")
article_head72 = soup72.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content72 = soup72.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data72= [[article_head72, article_content72]]
data72
# Out:
# [['How to Overcome Your Fear of Making Mistakes',
# ...

# %%
url73= 'https://insights.blackcoffer.com/is-perfection-the-greatest-enemy-of-productivity/'
page73= requests.get(url73)
page73
soup73 = BeautifulSoup(page73.content, "html.parser")
article_head73 = soup73.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content73 = soup73.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data73= [[article_head73, article_content73]]
data73
# Out:
# [['Is Perfection the Greatest enemy of Productivity?',
# ...

# %%
url74= 'https://insights.blackcoffer.com/global-financial-crisis-2008-causes-effects-and-its-solution/'
page74= requests.get(url74)
page74
soup74 = BeautifulSoup(page74.content, "html.parser")
article_head74 = soup74.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content74 = soup74.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data74= [[article_head74, article_content74]]
data74
# Out:
# [['Global financial crisis 2008 causes/effects and its solution',
# ...

# %%
url75= 'https://insights.blackcoffer.com/gender-diversity-and-equality-in-the-tech-industry/'
page75= requests.get(url75)
page75
soup75 = BeautifulSoup(page75.content, "html.parser")
article_head75 = soup75.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content75 = soup75.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data75= [[article_head75, article_content75]]
data75
# Out:
# [['Gender diversity and Equality in the tech industry',
# ...

# %%
url76= 'https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes/'
page76= requests.get(url76)
page76
soup76 = BeautifulSoup(page76.content, "html.parser")
article_head76 = soup76.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content76 = soup76.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data76= [[article_head76, article_content76]]
data76
# Out:
# [['How to overcome your fear of making mistakes?',
# ...

# %%
url77= 'https://insights.blackcoffer.com/how-small-business-can-survive-the-coronavirus-crisis/'
page77= requests.get(url77)
page77
soup77 = BeautifulSoup(page77.content, "html.parser")
article_head77 = soup77.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content77 = soup77.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data77= [[article_head77, article_content77]]
data77
# Out:
# [['How Small Business can survive the Coronavirus Crisis',
# ...

# %%
url78= 'https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors-and-food-stalls/'
page78= requests.get(url78)
page78
soup78 = BeautifulSoup(page78.content, "html.parser")
article_head78 = soup78.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content78 = soup78.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data78= [[article_head78, article_content78]]
data78
# Out:
# [['Impacts of COVID 19 on Food products',
# ...

# %%
url79= 'https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors/'
page79= requests.get(url79)
page79
soup79 = BeautifulSoup(page79.content, "html.parser")
article_head79 = soup79.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content79 = soup79.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data79= [[article_head79, article_content79]]
data79
# Out:
# [['Impacts of COVID 19 on Vegetable Vendors',
# ...

# %%
url80= 'https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-tourism-aviation-industries/'
page80= requests.get(url80)
page80
soup80 = BeautifulSoup(page80.content, "html.parser")
article_head80 = soup80.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content80 = soup80.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data80= [[article_head80, article_content80]]
data80
# Out:
# [['Impact of COVID-19 pandemic on Tourism & Aviation industries',
# ...

# %%
url81= 'https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-sports-events-around-the-world/'
page81= requests.get(url81)
page81
soup81 = BeautifulSoup(page81.content, "html.parser")
article_head81 = soup81.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content81 = soup81.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data81= [[article_head81, article_content81]]
data81
# Out:
# [['Impact of COVID-19 pandemic on sports events around the world.',
# ...

# %%
url82= 'https://insights.blackcoffer.com/changing-landscape-and-emerging-trends-in-the-indian-it-ites-industry/'
page82= requests.get(url82)
page82
soup82 = BeautifulSoup(page82.content, "html.parser")
article_head82 = soup82.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content82 = soup82.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data82= [[article_head82, article_content82]]
data82
# Out:
# [['Changing landscape and emerging trends in the Indian IT/ITeS Industry.',
# ...

# %%
url83= 'https://insights.blackcoffer.com/online-gaming-adolescent-online-gaming-effects-demotivated-depression-musculoskeletal-and-psychosomatic-symptoms/'
page83= requests.get(url83)
page83
soup83 = BeautifulSoup(page83.content, "html.parser")
article_head83 = soup83.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content83 = soup83.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data83= [[article_head83, article_content83]]
data83
# Out:
# [['Online gaming: Adolescent online gaming effects demotivated, depression, musculoskeletal, and psychosomatic symptoms.',
# ...

# %%
url84= 'https://insights.blackcoffer.com/human-rights-outlook/'
page84= requests.get(url84)
page84
soup84 = BeautifulSoup(page84.content, "html.parser")
article_head84 = soup84.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content84 = soup84.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data84= [[article_head84, article_content84]]
data84
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[138], line 5
#       3 page84
#       4 soup84 = BeautifulSoup(page84.content, "html.parser")
# ----> 5 article_head84 = soup84.find('h1', attrs = {'class' :'entry-title'}).text.strip()
#       6 article_content84 = soup84.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
#       7 data84= [[article_head84, article_content84]]
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
url85= 'https://insights.blackcoffer.com/how-voice-search-makes-your-business-a-successful-business/'
page85= requests.get(url85)
page85
soup85 = BeautifulSoup(page85.content, "html.parser")
article_head85 = soup85.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content85 = soup85.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data85= [[article_head85, article_content85]]
data85
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[139], line 5
#       3 page85
#       4 soup85 = BeautifulSoup(page85.content, "html.parser")
# ----> 5 article_head85 = soup85.find('h1', attrs = {'class' :'entry-title'}).text.strip()
#       6 article_content85 = soup85.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
#       7 data85= [[article_head85, article_content85]]
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
url86= 'https://insights.blackcoffer.com/how-the-covid-19-crisis-is-redefining-jobs-and-services/'
page86= requests.get(url86)
page86
soup86 = BeautifulSoup(page86.content, "html.parser")
article_head86 = soup86.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content86 = soup86.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data86= [[article_head86, article_content86]]
data86
# Out:
# [['How the COVID-19 crisis is redefining jobs and services?',
# ...

# %%
url87= 'https://insights.blackcoffer.com/how-to-increase-social-media-engagement-for-marketers/'
page87= requests.get(url87)
page87
soup87 = BeautifulSoup(page87.content, "html.parser")
article_head87 = soup87.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content87 = soup87.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data87= [[article_head87, article_content87]]
data87
# Out:
# [['How to increase social media engagement for marketers?',
# ...

# %%
url88= 'https://insights.blackcoffer.com/impacts-of-covid-19-on-streets-sides-food-stalls/'
page88= requests.get(url88)
page88
soup88 = BeautifulSoup(page88.content, "html.parser")
article_head88 = soup88.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content88 = soup88.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data88= [[article_head88, article_content88]]
data88
# Out:
# [['Impacts of COVID 19 on Streets Sides Food Stalls',
# ...

# %%
url89= 'https://insights.blackcoffer.com/coronavirus-impact-on-energy-markets-2/'
page89= requests.get(url89)
page89
soup89 = BeautifulSoup(page89.content, "html.parser")
article_head89 = soup89.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content89 = soup89.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data89= [[article_head89, article_content89]]
data89
# Out:
# [['Coronavirus impact on energy markets',
# ...

# %%
url90= 'https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry-5/'
page90= requests.get(url90)
page90
soup90 = BeautifulSoup(page90.content, "html.parser")
article_head90 = soup90.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content90 = soup90.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data90= [[article_head90, article_content90]]
data90
# Out:
# [['COVID-19 Impact on Hospitality Industry',
# ...

# %%
url91= 'https://insights.blackcoffer.com/lessons-from-the-past-some-key-learnings-relevant-to-the-coronavirus-crisis-4/'
page91= requests.get(url91)
page91
soup91 = BeautifulSoup(page91.content, "html.parser")
article_head91 = soup91.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content91 = soup91.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data91= [[article_head91, article_content91]]
data91
# Out:
# [['Lessons from the past: Some key learnings relevant to the coronavirus crisis',
# ...

# %%
url92= 'https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-2/'
page92= requests.get(url92)
page92
soup92 = BeautifulSoup(page92.content, "html.parser")
article_head92 = soup92.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content92 = soup92.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data92= [[article_head92, article_content92]]
data92
# Out:
# [['Estimating the impact of COVID-19 on the world of work',
# ...

# %%
url93= 'https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-3/'
page93= requests.get(url93)
page93
soup93 = BeautifulSoup(page93.content, "html.parser")
article_head93 = soup93.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content93 = soup93.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data93= [[article_head93, article_content93]]
data93
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[147], line 5
#       3 page93
#       4 soup93 = BeautifulSoup(page93.content, "html.parser")
# ----> 5 article_head93 = soup93.find('h1', attrs = {'class' :'entry-title'}).text.strip()
#       6 article_content93 = soup93.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
#       7 data93= [[article_head93, article_content93]]
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
url94= 'https://insights.blackcoffer.com/travel-and-tourism-outlook/'
page94= requests.get(url94)
page94
soup94 = BeautifulSoup(page94.content, "html.parser")
article_head94 = soup94.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content94 = soup94.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data94= [[article_head94, article_content94]]
data94
# Out:
# [['Travel and Tourism Outlook',
# ...

# %%
url95= 'https://insights.blackcoffer.com/gaming-disorder-and-effects-of-gaming-on-health/'
page95= requests.get(url95)
page95
soup95 = BeautifulSoup(page95.content, "html.parser")
article_head95 = soup95.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content95 = soup95.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data95= [[article_head95, article_content95]]
data95
# Out:
# [['Gaming Disorder and Effects of Gaming on Health.',
# ...

# %%
url96= 'https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation/'
page96= requests.get(url96)
page96
soup96 = BeautifulSoup(page96.content, "html.parser")
article_head96 = soup96.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content96 = soup96.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data96= [[article_head96, article_content96]]
data96
# Out:
# [['What is the repercussion of the environment due to the COVID-19 pandemic situation?',
# ...

# %%
url97= 'https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation-2/'
page97= requests.get(url97)
page97
soup97 = BeautifulSoup(page97.content, "html.parser")
article_head97 = soup97.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content97 = soup97.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data97= [[article_head97, article_content97]]
data97
# Out:
# [['Due to the COVID-19 the repercussion of the environment',
# ...

# %%
url98= 'https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-office-space-and-co-working-industries/'
page98= requests.get(url98)
page98
soup98 = BeautifulSoup(page98.content, "html.parser")
article_head98 = soup98.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content98 = soup98.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data98= [[article_head98, article_content98]]
data98
# Out:
# [['Impact of COVID-19 pandemic on office space and co-working industries.',
# ...

# %%
url99= 'https://insights.blackcoffer.com/contribution-of-handicrafts-visual-arts-literature-in-the-indian-economy/'
page99= requests.get(url99)
page99
soup99 = BeautifulSoup(page99.content, "html.parser")
article_head99 = soup99.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content99 = soup99.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data99= [[article_head99, article_content99]]
data99
# Out:
# [['Contribution of handicrafts (Visual Arts & Literature) in the Indian economy',
# ...

# %%
url100= 'https://insights.blackcoffer.com/how-covid-19-is-impacting-payment-preferences/'
page100= requests.get(url100)
page100
soup100 = BeautifulSoup(page100.content, "html.parser")
article_head100 = soup100.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content100 = soup100.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data100= [[article_head100, article_content100]]
data100
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[154], line 5
#       3 page100
#       4 soup100 = BeautifulSoup(page100.content, "html.parser")
# ----> 5 article_head100 = soup100.find('h1', attrs = {'class' :'entry-title'}).text.strip()
#       6 article_content100 = soup100.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
#       7 data100= [[article_head100, article_content100]]
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
url101= 'https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/'
page101= requests.get(url101)
page101
soup101 = BeautifulSoup(page101.content, "html.parser")
article_head101 = soup101.find('h1', attrs = {'class' :'entry-title'}).text.strip()
article_content101 = soup101.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
data101= [[article_head101, article_content101]]
data101
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[155], line 5
#       3 page101
#       4 soup101 = BeautifulSoup(page101.content, "html.parser")
# ----> 5 article_head101 = soup101.find('h1', attrs = {'class' :'entry-title'}).text.strip()
#       6 article_content101 = soup101.find('div', attrs = {'class' : 'td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
#       7 data101= [[article_head101, article_content101]]
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
# as from abve we have extracted most of the article heading and its content.
# but there are some url which was unable to extract as we have to define the path for the soup to find its tag and its class to extract

# %%
# the url are 13,20,29,36,43,49,83,84,92,99,100

# %%
# so we need to alter some of the elements in the code to get its article heading as well as its content

# %%
urlnew14= 'https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030-2/'
pagenew14= requests.get(urlnew14)
pagenew14
soupnew14 = BeautifulSoup(pagenew14.content, "html.parser")
article_headnew14 = soupnew14.find('h1', attrs = {'class' :'tdb-title-text'}).text.strip()
article_contentnew14 = soupnew14.find('div', attrs = {'class' : 'td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
datanew14= [[article_headnew14, article_contentnew14]]
datanew14
# Out:
# [['Rise of e-health and its impact on humans by the year 2030',
# ...

# %%
urlnew21= 'https://insights.blackcoffer.com/how-advertisement-increase-your-market-value/'
pagenew21= requests.get(urlnew21)
pagenew21
soupnew21 = BeautifulSoup(pagenew21.content, "html.parser")
article_headnew21 = soupnew21.find('h1', attrs = {'class' :'tdb-title-text'}).text.strip()
article_contentnew21 = soupnew21.find('div', attrs = {'class' : 'td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
datanew21= [[article_headnew21, article_contentnew21]]
datanew21
# Out:
# [['How advertisement increase your market value?',
# ...

# %%
urlnew30= 'https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/'
pagenew30= requests.get(urlnew30)
pagenew30
soupnew30 = BeautifulSoup(pagenew30.content, "html.parser")
article_headnew30 = soupnew30.find('h1', attrs = {'class' :'tdb-title-text'}).text.strip()
article_contentnew30 = soupnew30.find('div', attrs = {'class' : 'td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type'}).text.strip()
datanew30= [[article_headnew30, article_contentnew30]]
datanew30
# Out:
# [['AI in healthcare to Improve Patient Outcomes',
# ...

# %%
urlnew37= 'https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/'
pagenew37= requests.get(urlnew37)
pagenew37
soupnew37 = BeautifulSoup(pagenew37.content, "html.parser")
article_headnew37 = soupnew37.find('h1', attrs = {'class' :'tdb-title-text'}).text.strip()
article_contentnew37 = soupnew37.find('div', attrs = {'class' : 'td_block_wrap tdb_single_content tdi_137 td-pb-border-top td_block_template_1 td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
datanew37= [[article_headnew37, article_contentnew37]]
datanew37
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[163], line 5
#       3 pagenew37
#       4 soupnew37 = BeautifulSoup(pagenew37.content, "html.parser")
# ----> 5 article_headnew37 = soupnew37.find('h1', attrs = {'class' :'tdb-title-text'}).text.strip()
#       6 article_contentnew37 = soupnew37.find('div', attrs = {'class' : 'td_block_wrap tdb_single_content tdi_137 td-pb-border-top td_block_template_1 td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
#       7 datanew37= [[article_headnew37, article_contentnew37]]
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
page_response = requests.get(urlnew37)

# %%
page_response
# Out:
# <Response [404]>

# %%
# as the 36 url was not able to fetch due to the error 404 which was error from the domain it self

# %%
# so we will skip the url 36 and proceed further

# %%
urlnew44= 'https://insights.blackcoffer.com/future-of-work-how-ai-has-entered-the-workplace/'
pagenew44= requests.get(urlnew44)
pagenew44
soupnew44 = BeautifulSoup(pagenew44.content, "html.parser")
article_headnew44 = soupnew44.find('h1', attrs = {'class' :'tdb-title-text'}).text.strip()
article_contentnew44 = soupnew44.find('div', attrs = {'class' : 'td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
datanew44= [[article_headnew44, article_contentnew44]]
datanew44
# Out:
# [['Future of Work: How AI Has Entered the Workplace',
# ...

# %%
urlnew50= 'https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/'
pagenew50= requests.get(urlnew50)
pagenew50
soupnew50 = BeautifulSoup(pagenew50.content, "html.parser")
article_headnew50 = soupnew50.find('h1', attrs = {'class' :'tdb-title-text'}).text.strip()
article_contentnew50 = soupnew50.find('div', attrs = {'class' : 'td_block_wrap tdb_single_content tdi_150 td-pb-border-top td_block_template_1 td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
datanew50= [[article_headnew50, article_contentnew50]]
datanew50
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[169], line 5
#       3 pagenew50
#       4 soupnew50 = BeautifulSoup(pagenew50.content, "html.parser")
# ----> 5 article_headnew50 = soupnew50.find('h1', attrs = {'class' :'tdb-title-text'}).text.strip()
#       6 article_contentnew50 = soupnew50.find('div', attrs = {'class' : 'td_block_wrap tdb_single_content tdi_150 td-pb-border-top td_block_template_1 td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
#       7 datanew50= [[article_headnew50, article_contentnew50]]
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
urlnew50_response = requests.get(urlnew50)
urlnew50_response
# Out:
# <Response [404]>

# %%
# as the url 49 was unable to fetch from the domain as it have 404 error in the domain itself

# %%
urlnew84= 'https://insights.blackcoffer.com/human-rights-outlook/'
pagenew84= requests.get(urlnew84)
pagenew84
soupnew84 = BeautifulSoup(pagenew84.content, "html.parser")
article_headnew84 = soupnew84.find('h1', attrs = {'class' :'tdb-title-text'}).text.strip()
article_contentnew84 = soupnew84.find('div', attrs = {'class' : 'td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
datanew84= [[article_headnew84, article_contentnew84]]
datanew84
# Out:
# [['Human Rights Outlook',
# ...

# %%
urlnew85= 'https://insights.blackcoffer.com/how-voice-search-makes-your-business-a-successful-business/'
pagenew85= requests.get(urlnew85)
pagenew85
soupnew85 = BeautifulSoup(pagenew85.content, "html.parser")
article_headnew85 = soupnew85.find('h1', attrs = {'class' :'tdb-title-text'}).text.strip()
article_contentnew85 = soupnew85.find('div', attrs = {'class' : 'td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
datanew85= [[article_headnew85, article_contentnew85]]
datanew85
# Out:
# [['How Voice search makes your business a successful business.',
# ...

# %%
urlnew93= 'https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-3/'
pagenew93= requests.get(urlnew93)
pagenew93
soupnew93 = BeautifulSoup(pagenew93.content, "html.parser")
article_headnew93 = soupnew93.find('h1', attrs = {'class' :'tdb-title-text'}).text.strip()
article_contentnew93 = soupnew93.find('div', attrs = {'class' : 'td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
datanew93= [[article_headnew93, article_contentnew93]]
datanew93
# Out:
# [['Estimating the impact of COVID-19 on the world of work',
# ...

# %%
urlnew100= 'https://insights.blackcoffer.com/how-covid-19-is-impacting-payment-preferences/'
pagenew100= requests.get(urlnew100)
pagenew100
soupnew100 = BeautifulSoup(pagenew100.content, "html.parser")
article_headnew100 = soupnew100.find('h1', attrs = {'class' :'tdb-title-text'}).text.strip()
article_contentnew100 = soupnew100.find('div', attrs = {'class' : 'td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
datanew100= [[article_headnew100, article_contentnew100]]
datanew100
# Out:
# [['How COVID-19 is impacting payment preferences?',
# ...

# %%
urlnew101= 'https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/'
pagenew101= requests.get(urlnew101)
pagenew101
soupnew101 = BeautifulSoup(pagenew101.content, "html.parser")
article_headnew101 = soupnew101.find('h1', attrs = {'class' :'tdb-title-text'}).text.strip()
article_contentnew101 = soupnew101.find('div', attrs = {'class' : 'td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type'}).text.strip().replace('\n'," ").replace('\xa0'," ")
datanew101= [[article_headnew101, article_contentnew101]]
datanew101
# Out:
# [['How will COVID-19 affect the world of work?',
# ...

# %%
df0 = pd.DataFrame(data1,data2, columns = ['article_title','article_content'])

# %%
df0
# Out:
#                                                                                         article_title  \
# Rising IT Cities and Their Impact on the Econom...  Rising IT cities and its impact on the economy...
# Throughout history, from the industrial revolut...  Rising IT cities and its impact on the economy...
#
#                                                                                       article_content
# Rising IT Cities and Their Impact on the Econom...  We have seen a huge development and dependence...
# Throughout history, from the industrial revolut...  We have seen a huge development and dependence...

# %%
df00= pd.DataFrame(df0, columns=['article_title', "artilce_content"])
df00
csv_file = "data00.csv"
df00.to_csv('data00', index=False)

# %%
df00
# Out:
#                                                                                         article_title  \
# Rising IT Cities and Their Impact on the Econom...  Rising IT cities and its impact on the economy...
# Throughout history, from the industrial revolut...  Rising IT cities and its impact on the economy...
#
#                                                     artilce_content
# Rising IT Cities and Their Impact on the Econom...              NaN
# Throughout history, from the industrial revolut...              NaN

# %%
df00 = pd.DataFrame([data1,data2,data3,data4,data5,data6,data7,data8,data9,data10,data11,data12,data13,datanew14,data15,data16,data17,data18,data19,datanew21,data22,data23,data24,data25
])

# %%
df00.head()
# Out:
#                                                    0
# 0  [Rising IT cities and its impact on the econom...
# 1  [Rising IT Cities and Their Impact on the Econ...
# 2  [Internet Demand’s Evolution, Communication Im...
# 3  [Rise of Cybercrime and its Effect in upcoming...
# 4  [OTT platform and its impact on the entertainm...

# %%
df00.tail()
# Out:
#                                                     0
# 19  [How advertisement increase your market value?...
# 20  [Negative effects of marketing on society, “So...
# 21  [How advertisement/marketing affects business....
# 22  [Rising IT cities will impact the economy, env...
# 23  [Rise of OTT platform and its impact on entert...

# %%
df01 = pd.DataFrame([data26,data27,data28,data29,datanew30,data31,data32,data33,data34,data35,data36,data38,data39,data40,data41,data42,data43,datanew44,data45,data46,data47,data48,data49])

# %%
df01
# Out:
#                                                     0
# 0   [Rise of Electric Vehicles and its Impact on L...
# 1   [Rise of electric vehicle and its impact on li...
# 2   [Oil prices by the year 2040, and how it will ...
# 3   [An outlook of healthcare by the year 2040, an...
# 4   [AI in healthcare to Improve Patient Outcomes,...
# 5   [What if the Creation is Taking Over the Creat...
# 6   [What Jobs Will Robots Take From Humans in The...
# 7   [Will Machine Replace The Human in the Future ...
# 8   [Will AI Replace Us or Work With Us?, “Machine...
# 9   [Will machine replace the human in the future ...
# 10  [How humans and machines are evolving to work ...
# 11  [How machine learning will affect your busines...
# 12  [Deep learning impact on areas of e-learning?,...
# 13  [How to protect future data and its privacy?, ...
# 14  [How Machines, AI, Automations, and Robo-human...
# 15  [How Robo Human will Impact the Future?, It’s ...
# ...

# %%
df01.head()
# Out:
#                                                    0
# 0  [Rise of Electric Vehicles and its Impact on L...
# 1  [Rise of electric vehicle and its impact on li...
# 2  [Oil prices by the year 2040, and how it will ...
# 3  [An outlook of healthcare by the year 2040, an...
# 4  [AI in healthcare to Improve Patient Outcomes,...

# %%
df01.tail()
# Out:
#                                                     0
# 18  [How machine learning used in finance and bank...
# 19  [How AI will impact the future of work?, AI ex...
# 20  [All you need to know about online marketing, ...
# 21  [Evolution of Advertising Industry, Evolution ...
# 22  [How Data Analytics can help your business res...

# %%
df02 = pd.DataFrame([data51,data52,data53,data54,data55,data56,data57,data58,data59,data60,data61,data62,data63,data64,data65,data66,data67,data68,data69,data70,data71,data72,data73,data74,data75])

# %%
df02
# Out:
#                                                     0
# 0   [Environmental impact of the COVID-19 pandemic...
# 1   [How Data Analytics and AI are used to halt th...
# 2   [What is the difference between Artificial Int...
# 3   [How Python became the first choice for Data S...
# 4   [How Google fit measure heart and respiratory ...
# 5   [What is the future of mobile apps?, From what...
# 6   [Impact of AI in health and medicine, AI allow...
# 7   [What patients like and dislike about telemedi...
# 8   [How we forecast future technologies?, TECHNOL...
# 9   [Can robots tackle late-life loneliness?, In t...
# 10  [Embedding care robots into society and practi...
# 11  [Management challenges for future digitalizati...
# 12  [Are we any closer to preventing a nuclear hol...
# 13  [Will technology eliminate the need for animal...
# 14  [Will we ever understand the nature of conscio...
# 15  [Will we ever colonize outer space?, Nature ha...
# ...

# %%
df02.head(),df02.tail()
# Out:
# (                                                   0
#  0  [Environmental impact of the COVID-19 pandemic...
#  1  [How Data Analytics and AI are used to halt th...
#  2  [What is the difference between Artificial Int...
#  3  [How Python became the first choice for Data S...
#  4  [How Google fit measure heart and respiratory ...,
#                                                      0
#  20  [How does artificial intelligence affect the e...
#  21  [How to Overcome Your Fear of Making Mistakes,...
#  22  [Is Perfection the Greatest enemy of Productiv...
#  23  [Global financial crisis 2008 causes/effects a...
#  24  [Gender diversity and Equality in the tech ind...)

# %%
df03 = pd.DataFrame([data76,data77,data78,data79,data80,data81,data82,data83,datanew84,datanew85,data86,data87,data88,data89,data90,data91,data92,datanew93,data94,data95,data96,data97,data98,data99,datanew100,datanew101])

# %%
df03
# Out:
#                                                     0
# 0   [How to overcome your fear of making mistakes?...
# 1   [How Small Business can survive the Coronaviru...
# 2   [Impacts of COVID 19 on Food products, Some ve...
# 3   [Impacts of COVID 19 on Vegetable Vendors, The...
# 4   [Impact of COVID-19 pandemic on Tourism & Avia...
# 5   [Impact of COVID-19 pandemic on sports events ...
# 6   [Changing landscape and emerging trends in the...
# 7   [Online gaming: Adolescent online gaming effec...
# 8   [Human Rights Outlook, Climate change, technol...
# 9   [How Voice search makes your business a succes...
# 10  [How the COVID-19 crisis is redefining jobs an...
# 11  [How to increase social media engagement for m...
# 12  [Impacts of COVID 19 on Streets Sides Food Sta...
# 13  [Coronavirus impact on energy markets, The cor...
# 14  [COVID-19 Impact on Hospitality Industry, In D...
# 15  [Lessons from the past: Some key learnings rel...
# ...

# %%
df03.head(),df03.tail()
# Out:
# (                                                   0
#  0  [How to overcome your fear of making mistakes?...
#  1  [How Small Business can survive the Coronaviru...
#  2  [Impacts of COVID 19 on Food products, Some ve...
#  3  [Impacts of COVID 19 on Vegetable Vendors, The...
#  4  [Impact of COVID-19 pandemic on Tourism & Avia...,
#                                                      0
#  21  [Due to the COVID-19 the repercussion of the e...
#  22  [Impact of COVID-19 pandemic on office space a...
#  23  [Contribution of handicrafts (Visual Arts & Li...
#  24  [How COVID-19 is impacting payment preferences...
#  25  [How will COVID-19 affect the world of work?, ...)

# %%
dfall = ([df00,df01,df02,df03])

# %%
dfall
# Out:
# [                                                    0
#  0   [Rising IT cities and its impact on the econom...
#  1   [Rising IT Cities and Their Impact on the Econ...
#  2   [Internet Demand’s Evolution, Communication Im...
#  3   [Rise of Cybercrime and its Effect in upcoming...
#  4   [OTT platform and its impact on the entertainm...
#  5   [The rise of the OTT platform and its impact o...
#  6   [Rise of Cyber Crime and its Effects, Cybercri...
#  7   [Rise of Internet Demand and Its Impact on Com...
#  8   [Rise of Cybercrime and its Effect by the Year...
#  9   [Rise of Cybercrime and its Effect by the Year...
#  10  [Rise of Internet Demand and its Impact on Com...
#  11  [Rise of telemedicine and its Impact on Liveli...
#  12  [Rise of e-health and its impact on humans by ...
#  13  [Rise of e-health and its impact on humans by ...
#  14  [Rise of telemedicine and its Impact on Liveli...
#  15  [Rise of telemedicine and its Impact on Liveli...
# ...

# %%
df8.to_csv('data8', index=False)

# %%
#
